# %% [markdown]
# # CIRM Special
# This notebook is to make an animation to be shown at a conference at CIRM.

# %%
import scipy as sp
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import sys
sys.path.append('../../..')
print(sys.path)
from proximal.dynamicUOT import computeGeodesic

def image_to_numpy(image_path):
    # Load the image file
    image = Image.open(image_path).convert('L')  # Convert image to grayscale if it's not

    # Convert the PIL image to a numpy array
    image_array = np.array(image)

    return image_array

indicesx = np.arange(0, 156) * 1./156
indicesy = np.arange(0, 52) * 1./52
xx, yy = np.meshgrid(indicesx, indicesy)

rho_1 = (1-image_to_numpy('data/input/HAPPY BIRTHDAY PETER.png').squeeze()/255)
rho_0 = sp.stats.multivariate_normal.pdf(np.stack([xx, yy], axis=-1), mean=[78./156., 26./52.], cov=0.1)

rho_0 = rho_0 / np.sum(rho_0)
rho_1 = rho_1 / np.sum(rho_1)

T = 100
N1 = rho_1.shape[0]
N2 = rho_1.shape[1]

# plot rho_0 and rho_1
plt.figure(figsize=(10, 5))
plt.imshow(rho_0)
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(rho_1)
plt.show()
# Out:
# ['C:\\Users\\mao17\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip', 'C:\\Users\\mao17\\AppData\\Local\\Programs\\Python\\Python313\\DLLs', 'C:\\Users\\mao17\\AppData\\Local\\Programs\\Python\\Python313\\Lib', 'C:\\Users\\mao17\\AppData\\Local\\Programs\\Python\\Python313', 'c:\\Users\\mao17\\Workspace\\pdot\\venv', '', 'c:\\Users\\mao17\\Workspace\\pdot\\venv\\Lib\\site-packages', 'c:\\Users\\mao17\\Workspace\\pdot\\venv\\Lib\\site-packages\\win32', 'c:\\Users\\mao17\\Workspace\\pdot\\venv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\mao17\\Workspace\\pdot\\venv\\Lib\\site-packages\\Pythonwin', '../../../..', '../../..']

# %%
ll = (1.0, 1.0, 3.0)

x, lists = computeGeodesic(rho_0, rho_1, T, ll, p= 2.0, q=2.0, delta=1.0, niter=3000)
# Out:
# Computing a geodesic for optimal transport with source...
# Progress: 1%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 ll = (1.0, 1.0, 3.0)
# ----> 3 x, lists = computeGeodesic(rho_0, rho_1, T, ll, p= 2.0, q=2.0, delta=1.0, niter=3000)
#
# File c:\Users\mao17\Workspace\pdot\exploratory\proximal\unconstrained\../../..\proximal\dynamicUOT.py:521, in computeGeodesic(rho0, rho1, T, ll, H, F, p, q, delta, niter, alpha, gamma)
#     518 if i % (niter // 100) == 0:
#     519     print(f"\rProgress: {i // (niter // 100)}%", end="")
# --> 521 w, x, y, z = stepDR(
#     522     w,
#     523     x,
#     524     y,
#     525     z,
#     526     lambda y, x: prox1(y, x, source, gamma, p, q),
#     527     lambda y, x: prox2(y, x, Q, HQH, H, F),
#     528     alpha,
#     529 )
#     531 Flist[i] = z.energy(delta, p, q)
#     532 Clist[i] = z.dist_from_CE()
#
# File c:\Users\mao17\Workspace\pdot\exploratory\proximal\unconstrained\../../..\proximal\dynamicUOT.py:411, in stepDR(w, x, y, z, prox1, prox2, alpha)
#     408 w += alpha * (y - z)
#     410 # Step 4: Apply proximal operator 2 to w, updating z
# --> 411 prox2(z, w)
#     413 return w, x, y, z
#
# File c:\Users\mao17\Workspace\pdot\exploratory\proximal\unconstrained\../../..\proximal\dynamicUOT.py:527, in computeGeodesic.<locals>.<lambda>(y, x)
#     518 if i % (niter // 100) == 0:
#     519     print(f"\rProgress: {i // (niter // 100)}%", end="")
#     521 w, x, y, z = stepDR(
#     522     w,
#     523     x,
#     524     y,
#     525     z,
#     526     lambda y, x: prox1(y, x, source, gamma, p, q),
# --> 527     lambda y, x: prox2(y, x, Q, HQH, H, F),
#     528     alpha,
#     529 )
#     531 Flist[i] = z.energy(delta, p, q)
#     532 Clist[i] = z.dist_from_CE()
#
# File c:\Users\mao17\Workspace\pdot\exploratory\proximal\unconstrained\../../..\proximal\dynamicUOT.py:471, in computeGeodesic.<locals>.prox2(y, x, Q, HQH, H, F)
#     469 def prox2(y, x, Q, HQH=None, H=None, F=None):
#     470     if HQH is None or H is None or F is None:
# --> 471         projinterp_(y, x, Q)
#     472     else:
#     473         projinterp_constraint_(y, x, Q, HQH, H, F)
#
# File c:\Users\mao17\Workspace\pdot\exploratory\proximal\unconstrained\../../..\proximal\dynamicUOT.py:280, in projinterp_(dest, x, Q)
#     278 # Apply inverse Q matrix operation for each dimension
#     279 for k in range(dest.U.N):
# --> 280     invQ_mul_A_(dest.U.D[k], Q[k], dest.U.D[k], k, dest.nx)
#     282 # Average source terms (* adds x.V.Z(moved to dest.U by interpT_) and x.U.Z, so we
#     283 # only need to divide by 2 here)
#     284 dest.U.Z *= 0.5
#
# File c:\Users\mao17\Workspace\pdot\exploratory\proximal\unconstrained\../../..\proximal\dynamicUOT.py:230, in invQ_mul_A_(dest, Q, src, dim, nx)
#     227 remaining_shape = one_d_slices.shape[1:]
#     229 # Reshape the result to 2D
# --> 230 one_d_slices = one_d_slices.reshape(dim_shape, -1)
#     232 # Put the batch dimension to the first axis
#     233 # one_d_slices = nx.transpose(one_d_slices)
#     234
#     235 # Apply the inverse of Q to each slice
#     236 invQ_slices = nx.solve(Q, one_d_slices)
#
# KeyboardInterrupt:

# %%
from matplotlib.animation import FuncAnimation, PillowWriter, FFMpegWriter
import numpy as np

cmap = plt.cm.Greys

# Assuming plot_elements8, rho_0, rho_1, and T are defined elsewhere

global_min = min(rho_0.min(), rho_1.min(), x.V.D[0].min())
global_max = max(rho_0.max(), rho_1.max(), x.V.D[0].max())

fig, ax = plt.subplots(figsize=(5, 10))

def init():
    if T <= 0:
        im = ax.imshow(rho_0, cmap=cmap, vmin=global_min, vmax=global_max)
    else:
        im = ax.imshow(rho_1, cmap=cmap, vmin=global_min, vmax=global_max)
    ax.axis('off')  # Remove the axis
    return [im]

def update(t):
    ax.clear()
    if t <= 0:
        im = ax.imshow(rho_0, cmap, vmin=global_min, vmax=global_max)
    elif t >= T:
        im = ax.imshow(rho_1, cmap, vmin=global_min, vmax=global_max)
    else:
        im = ax.imshow(x.V.D[0][t], cmap, vmin=global_min, vmax=global_max)
    ax.axis('off')  # Remove the axis
    return [im]

ani = FuncAnimation(fig, update, frames=np.arange(0, T+1), init_func=init, blit=True)

# Save as GIF
ani.save('cirm_special.gif', writer=PillowWriter(fps=10))

# Save as MP4
ani.save('cirm_special.mp4', writer=FFMpegWriter(fps=10))

# %%
from matplotlib.animation import FuncAnimation, PillowWriter, FFMpegWriter
import numpy as np

cmap = plt.cm.viridis

# Assuming plot_elements8, rho_0, rho_1, and T are defined elsewhere

global_min = min(rho_0.min(), rho_1.min(), x.V.D[0].min())
global_max = max(rho_0.max(), rho_1.max(), x.V.D[0].max())

fig, ax = plt.subplots(figsize=(5, 10))

def init():
    if T <= 0:
        im = ax.imshow(rho_0, cmap=cmap, vmin=global_min, vmax=global_max)
    else:
        im = ax.imshow(rho_1, cmap=cmap, vmin=global_min, vmax=global_max)
    ax.axis('off')  # Remove the axis
    return [im]

def update(t):
    ax.clear()
    if t <= 0:
        im = ax.imshow(rho_0, cmap, vmin=global_min, vmax=global_max)
    elif t >= T:
        im = ax.imshow(rho_1, cmap, vmin=global_min, vmax=global_max)
    else:
        im = ax.imshow(x.V.D[0][t], cmap, vmin=global_min, vmax=global_max)
    ax.axis('off')  # Remove the axis
    return [im]

ani = FuncAnimation(fig, update, frames=np.arange(0, T+1), init_func=init, blit=True)

# Save as GIF
ani.save('cirm_special_viridis.gif', writer=PillowWriter(fps=10))

# Save as MP4
ani.save('cirm_special_viridis.mp4', writer=FFMpegWriter(fps=10))
