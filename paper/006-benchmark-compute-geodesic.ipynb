# %% [markdown]
# # Geodesic computation time
#
# Measure only `computeGeodesic`, reporting the mean, sample standard deviation, and individual runtimes in seconds. Each scenario runs three times by default; data loading, endpoint/constraint construction, input copies, and garbage collection are outside the timed section.
#
# The `legacy` group retains the existing paper benchmarks. Group `007` adds the primary Bayesian Gaussian-to-posterior geodesic. Group `008` adds WFR, no-lineage ACUOT, every configured partial-lineage ACUOT, and full-lineage ACUOT. The 0% and 100% cases reuse their named references, as in 008.
#
# Inputs and solver arguments for 007/008 come directly from selected cells in those notebooks. Their current settings and environment overrides (`ACUOT_BAYES_PROFILE`, `ACUOT_FAST_RUN`, `WFR_ROOT`, and `TOIAM_*`) apply. Preparation captures the solver calls without optimizing; each timed trial receives fresh copies. Solver progress output is disabled. The benchmark excludes plotting, weighted-particle generation, and 007's optional sequential online experiment.
#
# 007 uses its local or cached WFR artifacts and download setting; 008 requires the extracted TOIAM data. Missing input files are reported as skipped. Run from the repository root or `paper/`.

# %%
"""
The code to measure the average computation time of geodesic calculation for each setting in the paper.
"""

import os
import gc
import time
import numpy as np
import scipy as sp

import sys
from pathlib import Path

# Support launches from either the repository root or paper/.
_cwd = Path.cwd().resolve()
REPO_ROOT = next(
    (candidate for candidate in (_cwd, _cwd.parent)
     if (candidate / "src" / "acuot").is_dir()),
    None,
)
if REPO_ROOT is None:
    raise RuntimeError("Run this notebook from the repository root or paper/ directory.")
sys.path.insert(0, str(REPO_ROOT / "src"))
import acuot.dynamicUOT as dyn

# Base directory for test inputs (images/npz/npy). Override via env var if needed.
TEST_CASES_DIR = os.environ.get("TEST_CASES_DIR", str(REPO_ROOT / "tests" / "test_cases"))


# -----------------------------
# Scenario setup functions
# Each returns: (args_tuple, kwargs_dict) to pass into dyn.computeGeodesic
# -----------------------------


def setup_numpy_shk():
    # Define the initial and the terminal distributions
    T = 15
    K = 256

    X = np.linspace(0, 1, K)  # Discretization of the time-space domain
    rho_0 = np.exp(-0.5 * (X - 0.5) ** 2 / (0.05**2))
    rho_1 = 0.25 * np.exp(-0.5 * (X - 0.15) ** 2 / (0.05**2)) + 0.75 * np.exp(
        -0.5 * (X - 0.85) ** 2 / (0.05**2)
    )
    rho_0 /= np.sum(rho_0) / 256
    rho_1 /= np.sum(rho_1) / 256

    H = [[np.ones((T, K)), np.zeros((T, K)), np.zeros((T, K))]]
    GL = [np.ones(T)]
    GU = [np.ones(T)]
    args = (rho_0, rho_1, T, (1.0, 1.0))
    kwargs = dict(H=H, GL=GL, GU=GU, niter=10000)
    return args, kwargs


def setup_total_mass_inequality():
    def gauss(x, x_0, sigma, mass):
        normalized_factor = np.exp(-((x - x_0) ** 2) / sigma**2)
        return mass * (normalized_factor * K / np.sum(normalized_factor))

    sigma = 0.05
    K = 256
    X = np.linspace(0, 1, K)

    rho_0 = gauss(X, 0.25, sigma, 1)  # Initial density
    rho_1 = gauss(X, 0.75, sigma, 1)  # Final density

    rho_0 /= np.sum(rho_0) / 256
    rho_1 /= np.sum(rho_1) / 256

    T = 15
    ll = (1.0, 1.0)
    delta = 0.5 / np.pi

    H = [[np.ones((T, K)), np.zeros((T, K)), np.zeros((T, K))]]
    GL = [0.8 * np.ones((T,))]
    GU = [np.inf * np.ones((T,))]
    args = (rho_0, rho_1, T, ll)
    kwargs = dict(H=H, GL=GL, GU=GU, delta=delta, niter=3000)
    return args, kwargs


def setup_2d_total_mass():
    K = 30
    T = 15
    delta = 1.0
    rho_0 = np.load(os.path.join(TEST_CASES_DIR, "2D-total-mass-rho0.npy"))
    rho_1 = np.load(os.path.join(TEST_CASES_DIR, "2D-total-mass-rho1.npy"))

    t = np.array([(i + 0.5) / T for i in range(T)])
    F = 3 - 8 * (t - 0.5) ** 2
    GL = [F]
    GU = [F]
    H = [
        [
            np.ones((T, K, K)),
            np.zeros((T, K, K)),
            np.zeros((T, K, K)),
            np.zeros((T, K, K)),
        ]
    ]

    args = (rho_0, rho_1, T, (1.0, 1.0, 1.0))
    kwargs = dict(H=H, GL=GL, GU=GU, niter=3000, delta=delta)
    return args, kwargs


def _image_to_numpy(image_path):
    from PIL import Image

    image = Image.open(image_path).convert("L")
    return np.array(image)


def setup_barrier_static():
    maze = 1 - _image_to_numpy(os.path.join(TEST_CASES_DIR, "maze.png")).squeeze() / 255
    T = 30
    N1, N2 = maze.shape

    H = [
        [
            np.repeat(maze[np.newaxis, :, :], T, axis=0),
            np.zeros((T, N1, N2)),
            np.zeros((T, N1, N2)),
            np.zeros((T, N1, N2)),
        ]
    ]
    GL = [np.zeros(T)]
    GU = [np.zeros(T)]

    indices = np.arange(0, 30) * 1.0 / 30
    xx, yy = np.meshgrid(indices, indices)

    rho_0 = sp.stats.multivariate_normal.pdf(
        np.stack([xx, yy], axis=-1), mean=[5.0 / 30.0, 5.0 / 30.0], cov=2.0 / 36**2
    )
    rho_1 = sp.stats.multivariate_normal.pdf(
        np.stack([xx, yy], axis=-1), mean=[24.0 / 30.0, 24.0 / 30.0], cov=2.0 / 36**2
    )
    ll = (1.0, 1.0, 1.0)
    args = (rho_0, rho_1, T, ll)
    kwargs = dict(H=H, GL=GL, GU=GU, delta=10.0, niter=7000)
    return args, kwargs


def setup_barrier_moving():
    def fill_region(frames, fps, speed, original, Hstep):
        rows, cols = 30, 30
        step_size = speed * 14 / fps
        start_col, end_col = 1, 14
        filled_frames = [original]
        for i in range(1, frames):
            frame = filled_frames[-1].copy()
            end_fill = max(1, int(end_col - i * step_size))
            frame[18:20, end_fill:14] += Hstep
            frame[frame > 1] = 1
            filled_frames.append(frame.copy())
        return filled_frames

    maze = 1 - _image_to_numpy(os.path.join(TEST_CASES_DIR, "maze.png")).squeeze() / 255
    T = 30
    N1, N2 = maze.shape
    frames = fill_region(T, 30, 1.0, maze, Hstep=1.0)
    barrier = np.stack(frames, axis=0)

    H = [
        [
            barrier,
            np.zeros((T, N1, N2)),
            np.zeros((T, N1, N2)),
            np.zeros((T, N1, N2)),
        ]
    ]
    GL = [np.zeros(T)]
    GU = [np.zeros(T)]

    indices = np.arange(0, 30) * 1.0 / 30
    xx, yy = np.meshgrid(indices, indices)

    rho_0 = sp.stats.multivariate_normal.pdf(
        np.stack([xx, yy], axis=-1), mean=[5.0 / 30.0, 5.0 / 30.0], cov=2.0 / 36**2
    )
    rho_1 = sp.stats.multivariate_normal.pdf(
        np.stack([xx, yy], axis=-1), mean=[24.0 / 30.0, 24.0 / 30.0], cov=2.0 / 36**2
    )
    ll = (1.0, 1.0, 1.0)
    args = (rho_0, rho_1, T, ll)
    kwargs = dict(H=H, GL=GL, GU=GU, delta=10.0, niter=7000)
    return args, kwargs


def setup_ain():
    inputs = np.load(os.path.join(TEST_CASES_DIR, "ain-inputs.npz"))
    rho_0 = inputs["rho_0"]
    rho_1 = inputs["rho_1"]
    H1 = inputs["H1"]
    H2 = inputs["H2"]
    F1 = inputs["F1"]
    F2 = inputs["F2"]
    T = int(inputs["T"].item())
    ll = tuple(inputs["ll"])
    niter = int(inputs["niter"].item())
    N = rho_0.shape[0]
    H = [
        [H1, np.zeros((T, N, N)), np.zeros((T, N, N)), np.zeros((T, N, N))],
        [H2, np.zeros((T, N, N)), np.zeros((T, N, N)), np.zeros((T, N, N))],
    ]
    GL = [F1, F2]
    GU = [F1, F2]
    args = (rho_0, rho_1, T, ll)
    kwargs = dict(H=H, GL=GL, GU=GU, niter=niter, delta=1.0)
    return args, kwargs


def setup_curve_symmetric():
    def wrap(x):
        return (x + np.pi) % (2 * np.pi) - np.pi

    def gaussian_on_circle(t, mu, sigma):
        return np.exp(-0.5 * wrap(t - mu) ** 2 / sigma**2)

    def rho_two_bumps(theta, mu=0.0, sigma=0.25):
        g1 = gaussian_on_circle(theta, mu, sigma)
        g2 = gaussian_on_circle(theta, mu + np.pi, sigma)
        return g1 + g2

    def normalize_density(rho, desired_mass=1.0):
        dx = 2 * np.pi / rho.size
        return rho / (rho.sum() * dx) * desired_mass

    def make_HF(theta, T):
        H = [
            np.tile(np.cos(theta), (T, 1)),
            np.tile(np.sin(theta), (T, 1)),
        ]
        F = [np.zeros(T), np.zeros(T)]
        return H, F

    sigma = 0.2
    T = 15
    K = 256
    ll = (1.0, 2 * np.pi)
    theta_grid = np.linspace(0.0, 2 * np.pi, K, endpoint=False)

    rho_0 = rho_two_bumps(theta_grid, mu=0.0, sigma=sigma)
    rho_1 = (
        gaussian_on_circle(theta_grid, mu=np.pi / 4, sigma=sigma)
        + gaussian_on_circle(theta_grid, mu=3 * np.pi / 4, sigma=sigma)
        + gaussian_on_circle(theta_grid, mu=5 * np.pi / 4, sigma=sigma)
        + gaussian_on_circle(theta_grid, mu=7 * np.pi / 4, sigma=sigma)
    )

    rho_0 = normalize_density(rho_0, desired_mass=1.0)
    rho_1 = normalize_density(rho_1, desired_mass=2.0)
    H, F = make_HF(theta_grid, T)
    H = [
        [H[0], np.zeros((T, K)), np.zeros((T, K))],
        [H[1], np.zeros((T, K)), np.zeros((T, K))],
    ]
    GL = F
    GU = F
    args = (rho_0, rho_1, T, ll)
    kwargs = dict(H=H, GL=GL, GU=GU, niter=10000, delta=0.01, periodic=True)
    return args, kwargs


def setup_curve_unsymmetric():
    def wrap(x):
        return (x + np.pi) % (2 * np.pi) - np.pi

    def gaussian_on_circle(t, mu, sigma):
        return np.exp(-0.5 * wrap(t - mu) ** 2 / sigma**2)

    def rho_two_bumps(theta, mu=0.0, sigma=0.25):
        g1 = gaussian_on_circle(theta, mu, sigma)
        g2 = gaussian_on_circle(theta, mu + np.pi, sigma)
        return g1 + g2

    def normalize_density(rho, desired_mass=1.0):
        dx = 2 * np.pi / rho.size
        return rho / (rho.sum() * dx) * desired_mass

    def make_HF(theta, T):
        H = [
            np.tile(np.cos(theta), (T, 1)),
            np.tile(np.sin(theta), (T, 1)),
        ]
        F = [np.zeros(T), np.zeros(T)]
        return H, F

    sigma = 0.2
    T = 15
    K = 256
    ll = (1.0, 2 * np.pi)
    theta_grid = np.linspace(0.0, 2 * np.pi, K, endpoint=False)

    rho_0 = rho_two_bumps(theta_grid, mu=0.0, sigma=sigma)
    rho_1 = (
        gaussian_on_circle(theta_grid, mu=0, sigma=sigma)
        + gaussian_on_circle(theta_grid, mu=2 * np.pi / 3, sigma=sigma)
        + gaussian_on_circle(theta_grid, mu=4 * np.pi / 3, sigma=sigma)
    )

    rho_0 = normalize_density(rho_0, desired_mass=1.0)
    rho_1 = normalize_density(rho_1, desired_mass=2.0)
    H, F = make_HF(theta_grid, T)
    H = [
        [H[0], np.zeros((T, K)), np.zeros((T, K))],
        [H[1], np.zeros((T, K)), np.zeros((T, K))],
    ]
    GL = F
    GU = F
    args = (rho_0, rho_1, T, ll)
    kwargs = dict(H=H, GL=GL, GU=GU, niter=10000, delta=0.01, periodic=True)
    return args, kwargs


def setup_river():
    maze = np.zeros((30, 30))
    maze[13:17, 0:30] = 1

    T = 15
    N1, N2 = maze.shape

    H1 = np.repeat(maze[np.newaxis, :, :], T, axis=0) * np.cos(np.pi / 4)
    H2 = np.repeat(maze[np.newaxis, :, :], T, axis=0) * np.sin(np.pi / 4)

    indices = np.arange(0, 30) * 1.0 / 30
    xx, yy = np.meshgrid(indices, indices)

    rho_0 = sp.stats.multivariate_normal.pdf(
        np.stack([xx, yy], axis=-1), mean=[15.0 / 30.0, 20.0 / 30.0], cov=2.0 / 36**2
    )
    rho_1 = sp.stats.multivariate_normal.pdf(
        np.stack([xx, yy], axis=-1), mean=[15.0 / 30.0, 8.0 / 30.0], cov=2.0 / 36**2
    )

    ll = (1.0, 1.0, 1.0)
    delta = 2.0
    Hs = [[np.zeros((T, N1, N2)), H1, H2, np.zeros((T, N1, N2))]]
    GL = [np.zeros((T,))]
    GU = [np.ones((T,)) * np.inf]
    args = (rho_0, rho_1, T, ll)
    kwargs = dict(H=Hs, GL=GL, GU=GU, p=2.0, q=2.0, delta=delta, niter=3000)
    return args, kwargs


def setup_budget():
    def gauss(x, x_0, sigma, mass, K):
        normalized_factor = np.exp(-((x - x_0) ** 2) / sigma**2)
        return mass * (normalized_factor * K / np.sum(normalized_factor))

    sigma = 0.03
    K = 256
    X = np.linspace(0, 1, K)

    rho_0 = gauss(X, 0.25, sigma, 1, K)
    rho_1 = gauss(X, 0.75, sigma, 1, K)

    rho_0 /= np.sum(rho_0) / 256
    rho_1 /= np.sum(rho_1) / (256 * 2)

    rho_0 = rho_0.astype(np.float64)
    rho_1 = rho_1.astype(np.float64)

    T = 15
    ll = (1.0, 1.0)

    # Step mask boundary (right half)
    H_start_x = 0.5
    j0 = int(np.clip(int(np.floor(H_start_x * K)), 0, K - 1))

    H_vec = np.zeros((K,), dtype=float)
    H_vec[j0:] = 1.0
    H = np.tile(H_vec, (T, 1))

    Hs = [[np.zeros((T, K)), np.zeros((T, K)), H]]
    GL = [np.zeros((T,))]
    GU = [0.1 * np.ones((T,))]
    args = (rho_0, rho_1, T, ll)
    kwargs = dict(H=Hs, GL=GL, GU=GU, p=2.0, q=2.0, delta=0.5 / np.pi, niter=3000)
    return args, kwargs

# %% [markdown]
# ## Inputs from notebooks 007 and 008

# %%
import contextlib
import copy
from functools import partial
import io
import json


def fresh_inputs(inputs):
    """Give every timed solve its own endpoints, constraints, and bounds."""
    return copy.deepcopy(inputs)


def prepare_notebook_inputs(filename, setup_cell_ids, solve_cell_ids):
    """Run preparation, then capture solver arguments without solving a geodesic."""
    path = REPO_ROOT / "paper" / filename
    notebook = json.loads(path.read_text(encoding="utf-8"))
    cells = {
        cell["id"]: "".join(cell["source"])
        for cell in notebook["cells"] if cell["cell_type"] == "code"
    }
    missing = set((*setup_cell_ids, *solve_cell_ids)) - cells.keys()
    if missing:
        raise ValueError(f"Missing benchmark input cells in {filename}: {sorted(missing)}")
    namespace = {"__name__": "__benchmark_setup__", "__file__": str(path)}

    def capture_compute_geodesic(*args, **kwargs):
        # Progress output is disabled for consistent timing across scenarios.
        kwargs["verbose"] = False
        return fresh_inputs((args, kwargs)), None

    # Data loading, constraint construction, and input copies are never timed.
    # Only these selected cells run: no plots, field diagnostics, or sampling.
    with contextlib.redirect_stdout(io.StringIO()):
        for cell_id in setup_cell_ids:
            exec(compile(cells[cell_id], f"{path}:{cell_id}", "exec"), namespace)
        namespace["computeGeodesic"] = capture_compute_geodesic
        for cell_id in solve_cell_ids:
            exec(compile(cells[cell_id], f"{path}:{cell_id}", "exec"), namespace)
    return namespace


def bayesian_benchmarks():
    """007's primary Gaussian-to-posterior solve, using its active profile."""
    prepared = prepare_notebook_inputs(
        "007-bayesian-sampling-bernoulli.ipynb",
        setup_cell_ids=("a6c9bddd", "1d877654", "f4faacdd", "74ff7621"),
        solve_cell_ids=("b6d3cc23",),
    )
    return {
        "bayesian_bernoulli": partial(fresh_inputs, prepared["geodesic"]),
    }


def toiam_benchmarks():
    """008's distinct WFR/ACUOT solves, with one case per lineage percentage."""
    prepared = prepare_notebook_inputs(
        "008-toiam-dispersion-constraint.ipynb",
        setup_cell_ids=(
            "imports-config", "manuscript-figure-helpers", "experiment-config",
            "loader-helpers", "load-window", "build-observations",
            "source-intervals", "assemble-constraints",
        ),
        solve_cell_ids=("wfr-delta-experiments", "acuot-solves"),
    )
    inputs = {
        "toiam_wfr": prepared["wfr_solution"],
        "toiam_no_lineage": prepared["no_lineage_solution"],
    }
    for percentage, result in prepared["configured_solutions"].items():
        # 0% and 100% reuse the named no-lineage/full-lineage solves in 008.
        if percentage not in (0, 100):
            inputs[f"toiam_lineage_{percentage:g}pct"] = result[0]
    inputs["toiam_full_lineage"] = prepared["full_solution"]
    return {name: partial(fresh_inputs, spec) for name, spec in inputs.items()}

# %% [markdown]
# ## Timing harness

# %%
def time_compute_geodesic(setup_fn, tries=3):
    """Return solver-only durations in seconds, using fresh inputs each trial."""
    if isinstance(tries, bool) or not isinstance(tries, (int, np.integer)) or tries < 1:
        raise ValueError("tries must be a positive integer.")
    times = []
    for _ in range(tries):
        args, kwargs = setup_fn()
        gc.collect()
        t0 = time.perf_counter()
        result = dyn.computeGeodesic(*args, **kwargs)
        t1 = time.perf_counter()
        times.append(t1 - t0)
        del result
        gc.collect()
    return times


def legacy_benchmarks():
    return {
        "numpy_shk": setup_numpy_shk,
        "total_mass_inequality": setup_total_mass_inequality,
        "2d_total_mass": setup_2d_total_mass,
        "barrier_static": setup_barrier_static,
        "barrier_moving": setup_barrier_moving,
        "ain": setup_ain,
        "curve_symmetric": setup_curve_symmetric,
        "curve_unsymmetric": setup_curve_unsymmetric,
        "river": setup_river,
        "budget": setup_budget,
    }


def main(tries=3, groups=("legacy", "007", "008")):
    """Benchmark selected notebook groups and return their timing records."""
    if isinstance(tries, bool) or not isinstance(tries, (int, np.integer)) or tries < 1:
        raise ValueError("tries must be a positive integer.")
    loaders = {
        "legacy": legacy_benchmarks,
        "007": bayesian_benchmarks,
        "008": toiam_benchmarks,
    }
    groups = (groups,) if isinstance(groups, str) else tuple(groups)
    if not groups or len(set(groups)) != len(groups) or any(group not in loaders for group in groups):
        raise ValueError("groups must select unique names from 'legacy', '007', and '008'.")

    print(f"Benchmarking dyn.computeGeodesic ({tries} tries per scenario)\n")
    header = f"{'Scenario':<30} {'Mean (s)':>12} {'Std (s)':>12}  Runs (s)"
    print(header)
    print("-" * len(header))
    results = []
    for group in groups:
        # Prepare each notebook once; trial setup then copies the captured inputs.
        try:
            benchmarks = loaders[group]()
        except FileNotFoundError as error:
            print(f"{group:<30} {'N/A':>12} {'N/A':>12}  skipped (missing file: {error})")
            continue
        except Exception as error:
            print(f"{group:<30} {'ERR':>12} {'ERR':>12}  setup error: {error}")
            continue
        for name, setup_fn in benchmarks.items():
            try:
                durations = time_compute_geodesic(setup_fn, tries=tries)
                mean = float(np.mean(durations))
                std = float(np.std(durations, ddof=1)) if len(durations) > 1 else 0.0
                runs_str = ", ".join(f"{duration:.3f}" for duration in durations)
                print(f"{name:<30} {mean:>12.3f} {std:>12.3f}  {runs_str}")
                results.append({
                    "scenario": name, "mean_seconds": mean,
                    "std_seconds": std, "runs_seconds": durations,
                })
            except FileNotFoundError as error:
                print(f"{name:<30} {'N/A':>12} {'N/A':>12}  skipped (missing file: {error})")
            except Exception as error:
                print(f"{name:<30} {'ERR':>12} {'ERR':>12}  error: {error}")
    print("\nDone.")
    return results

# %% [markdown]
# ## Run the benchmarks
#
# Set `BENCHMARK_GROUPS = ("007", "008")` to time only the added scenarios, or use `("007",)` / `("008",)` for one notebook. Set `BENCHMARK_TRIES` to change the number of repetitions. Results remain available as numeric records in `benchmark_results`. Rerunning this cell reloads the source notebooks and their settings.

# %%
BENCHMARK_TRIES = 3
BENCHMARK_GROUPS = ("legacy", "007", "008")

benchmark_results = main(tries=BENCHMARK_TRIES, groups=BENCHMARK_GROUPS)
